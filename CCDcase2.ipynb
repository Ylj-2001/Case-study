# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data12A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data12S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data12I_points.csv',header=None)
data1 = np.array(data1)

n = 10

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (1/2-1/40 < data[i,0] < 1/2) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (1/2-2/40 < data[i,0] < 1/4-1/40) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (1/2-3/40 < data[i,0] < 1/2-2/40) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (1/2-4/40 < data[i,0] < 1/2-3/40) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (1/2-5/40 < data[i,0] < 1/2-4/40) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (1/2-6/40 < data[i,0] < 1/2-5/40) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (1/2-7/40 < data[i,0] < 1/2-6/40) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (1/2-8/40 < data[i,0] < 1/2-7/40) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (1/2-9/40 < data[i,0] < 1/2-8/40) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (1/2-10/40 < data[i,0] < 1/2-9/40) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (1/2-11/40 < data[i,0] < 1/2-10/40) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (1/2-12/40 < data[i,0] < 1/2-11/40) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (1/2-13/40 < data[i,0] < 1/2-12/40) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (1/2-14/40 < data[i,0] < 1/2-13/40) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (1/2-15/40 < data[i,0] < 1/2-14/40) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (1/2-16/40 < data[i,0] < 1/2-15/40) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (1/2-17/40 < data[i,0] < 1/2-16/40) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (1/2-18/40 < data[i,0] < 1/2-17/40) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (1/2-19/40 < data[i,0] < 1/2-18/40) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,0] < 1/2-19/40) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 1
# Number of points inside the polygon: 0
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# 中心复合差异 CCD_p(P): 0.05000000000000002
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 1
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data22A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data22S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data22I_points.csv',header=None)
data1 = np.array(data1)

n = 20

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (1/2-1/40 < data[i,0] < 1/2) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (1/2-2/40 < data[i,0] < 1/4-1/40) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (1/2-3/40 < data[i,0] < 1/2-2/40) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (1/2-4/40 < data[i,0] < 1/2-3/40) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (1/2-5/40 < data[i,0] < 1/2-4/40) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (1/2-6/40 < data[i,0] < 1/2-5/40) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (1/2-7/40 < data[i,0] < 1/2-6/40) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (1/2-8/40 < data[i,0] < 1/2-7/40) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (1/2-9/40 < data[i,0] < 1/2-8/40) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (1/2-10/40 < data[i,0] < 1/2-9/40) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (1/2-11/40 < data[i,0] < 1/2-10/40) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (1/2-12/40 < data[i,0] < 1/2-11/40) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (1/2-13/40 < data[i,0] < 1/2-12/40) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (1/2-14/40 < data[i,0] < 1/2-13/40) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (1/2-15/40 < data[i,0] < 1/2-14/40) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (1/2-16/40 < data[i,0] < 1/2-15/40) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (1/2-17/40 < data[i,0] < 1/2-16/40) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (1/2-18/40 < data[i,0] < 1/2-17/40) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (1/2-19/40 < data[i,0] < 1/2-18/40) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,0] < 1/2-19/40) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n

 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 2
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# Number of points inside the polygon: 1
# 中心复合差异 CCD_p(P): 0.03354101966249685
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data32A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data32S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data32I_points.csv',header=None)
data1 = np.array(data1)

n = 30

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (0.475 < data[i,0] < 0.5) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (0.45 < data[i,0] < 0.475) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (0.425 < data[i,0] < 0.45) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (0.4 < data[i,0] < 0.425) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (0.375 < data[i,0] < 0.4) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (0.35 < data[i,0] < 0.375) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (0.325 < data[i,0] < 0.35) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (0.3 < data[i,0] < 0.325) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (0.275 < data[i,0] < 0.3) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (0.25 < data[i,0] < 0.275) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (0.225 < data[i,0] < 0.25) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (0.2 < data[i,0] < 0.225) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (0.175 < data[i,0] < 0.2) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (0.15 < data[i,0] < 0.175) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (0.125 < data[i,0] < 0.15) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (0.1 < data[i,0] < 0.125) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (0.075 < data[i,0] < 0.1) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (0.05 < data[i,0] < 0.075) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (0.025 < data[i,0] < 0.05) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,0] < 0.025) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# 中心复合差异 CCD_p(P): 0.026874192494328503
# Number of points inside the polygon: 5
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data42A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data42S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data42I_points.csv',header=None)
data1 = np.array(data1)

n = 40

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (0.475 < data[i,0] < 0.5) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (0.45 < data[i,0] < 0.475) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (0.425 < data[i,0] < 0.45) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (0.4 < data[i,0] < 0.425) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (0.375 < data[i,0] < 0.4) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (0.35 < data[i,0] < 0.375) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (0.325 < data[i,0] < 0.35) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (0.3 < data[i,0] < 0.325) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (0.275 < data[i,0] < 0.3) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (0.25 < data[i,0] < 0.275) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (0.225 < data[i,0] < 0.25) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (0.2 < data[i,0] < 0.225) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (0.175 < data[i,0] < 0.2) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (0.15 < data[i,0] < 0.175) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (0.125 < data[i,0] < 0.15) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (0.1 < data[i,0] < 0.125) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (0.075 < data[i,0] < 0.1) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (0.05 < data[i,0] < 0.075) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (0.025 < data[i,0] < 0.05) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,0] < 0.025) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# 中心复合差异 CCD_p(P): 0.026809513236909027
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data52A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data52S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data52I_points.csv',header=None)
data1 = np.array(data1)

n = 50

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (0.475 < data[i,0] < 0.5) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (0.45 < data[i,0] < 0.475) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (0.425 < data[i,0] < 0.45) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (0.4 < data[i,0] < 0.425) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (0.375 < data[i,0] < 0.4) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (0.35 < data[i,0] < 0.375) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (0.325 < data[i,0] < 0.35) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (0.3 < data[i,0] < 0.325) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (0.275 < data[i,0] < 0.3) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (0.25 < data[i,0] < 0.275) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (0.225 < data[i,0] < 0.25) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (0.2 < data[i,0] < 0.225) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (0.175 < data[i,0] < 0.2) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (0.15 < data[i,0] < 0.175) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (0.125 < data[i,0] < 0.15) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (0.1 < data[i,0] < 0.125) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (0.075 < data[i,0] < 0.1) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (0.05 < data[i,0] < 0.075) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (0.025 < data[i,0] < 0.05) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,0] < 0.025) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# 中心复合差异 CCD_p(P): 0.025690465157330252
# Number of points inside the polygon: 5
# Number of points inside the polygon: 2
# Number of points inside the polygon: 4
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data62A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data62S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data62I_points.csv',header=None)
data1 = np.array(data1)

n = 60

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (0.475 < data[i,0] < 0.5) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (0.45 < data[i,0] < 0.475) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (0.425 < data[i,0] < 0.45) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (0.4 < data[i,0] < 0.425) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (0.375 < data[i,0] < 0.4) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (0.35 < data[i,0] < 0.375) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (0.325 < data[i,0] < 0.35) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (0.3 < data[i,0] < 0.325) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (0.275 < data[i,0] < 0.3) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (0.25 < data[i,0] < 0.275) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (0.225 < data[i,0] < 0.25) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (0.2 < data[i,0] < 0.225) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (0.175 < data[i,0] < 0.2) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (0.15 < data[i,0] < 0.175) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (0.125 < data[i,0] < 0.15) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (0.1 < data[i,0] < 0.125) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (0.075 < data[i,0] < 0.1) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (0.05 < data[i,0] < 0.075) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (0.025 < data[i,0] < 0.05) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,0] < 0.025) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 0
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# 中心复合差异 CCD_p(P): 0.025549516194593155
# Number of points inside the polygon: 1
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data72A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data72S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data72I_points.csv',header=None)
data1 = np.array(data1)

n = 70

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (1/3-1/60 < data[i,1] < 1/3) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (1/3-2/60 < data[i,1] < 1/3-1/60) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (1/3-3/60 < data[i,1] < 1/3-2/60) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (1/3-4/60 < data[i,1] < 1/3-3/60) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (1/3-5/60 < data[i,1] < 1/3-4/60) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (1/3-6/60 < data[i,1] < 1/3-5/60) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (1/3-7/60 < data[i,1] < 1/3-6/60) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (1/3-8/60 < data[i,1] < 1/3-7/60) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (1/3-9/60 < data[i,1] < 1/3-8/60) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (1/3-10/60 < data[i,1] < 1/3-9/60) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (1/3-11/60 < data[i,1] < 1/3-10/60) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (1/3-12/60 < data[i,1] < 1/3-11/60) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (1/3-13/60 < data[i,1] < 1/3-12/60) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (1/3-14/60 < data[i,1] < 1/3-13/60) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (1/3-15/60 < data[i,1] < 1/3-14/60) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (1/3-16/60 < data[i,1] < 1/3-15/60) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (1/3-17/60 < data[i,1] < 1/3-16/60) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (1/3-18/60 < data[i,1] < 1/3-17/60) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (1/3-19/60 < data[i,1] < 1/3-18/60) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,1] < 1/3-19/60) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 0
# Number of points inside the polygon: 2
# Number of points inside the polygon: 2
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 5
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 4
# Number of points inside the polygon: 5
# Number of points inside the polygon: 4
# 中心复合差异 CCD_p(P): 0.017202277969703274
# Number of points inside the polygon: 6
# Number of points inside the polygon: 6
# Number of points inside the polygon: 4
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data82A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data82S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data82I_points.csv',header=None)
data1 = np.array(data1)

n = 80

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (1/3-1/60 < data[i,1] < 1/3) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (1/3-2/60 < data[i,1] < 1/3-1/60) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (1/3-3/60 < data[i,1] < 1/3-2/60) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (1/3-4/60 < data[i,1] < 1/3-3/60) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (1/3-5/60 < data[i,1] < 1/3-4/60) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (1/3-6/60 < data[i,1] < 1/3-5/60) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (1/3-7/60 < data[i,1] < 1/3-6/60) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (1/3-8/60 < data[i,1] < 1/3-7/60) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (1/3-9/60 < data[i,1] < 1/3-8/60) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (1/3-10/60 < data[i,1] < 1/3-9/60) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (1/3-11/60 < data[i,1] < 1/3-10/60) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (1/3-12/60 < data[i,1] < 1/3-11/60) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (1/3-13/60 < data[i,1] < 1/3-12/60) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (1/3-14/60 < data[i,1] < 1/3-13/60) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (1/3-15/60 < data[i,1] < 1/3-14/60) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (1/3-16/60 < data[i,1] < 1/3-15/60) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (1/3-17/60 < data[i,1] < 1/3-16/60) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (1/3-18/60 < data[i,1] < 1/3-17/60) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (1/3-19/60 < data[i,1] < 1/3-18/60) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,1] < 1/3-19/60) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 4
# Number of points inside the polygon: 2
# Number of points inside the polygon: 4
# Number of points inside the polygon: 5
# Number of points inside the polygon: 2
# Number of points inside the polygon: 5
# Number of points inside the polygon: 5
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 7
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 6
# Number of points inside the polygon: 4
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 6
# Number of points inside the polygon: 5
# 中心复合差异 CCD_p(P): 0.020155644370746375
# Number of points inside the polygon: 2
# Number of points inside the polygon: 9
# Number of points inside the polygon: 5
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data92A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data92S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data92I_points.csv',header=None)
data1 = np.array(data1)

n = 90

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (1/3-1/60 < data[i,1] < 1/3) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (1/3-2/60 < data[i,1] < 1/3-1/60) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (1/3-3/60 < data[i,1] < 1/3-2/60) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (1/3-4/60 < data[i,1] < 1/3-3/60) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (1/3-5/60 < data[i,1] < 1/3-4/60) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (1/3-6/60 < data[i,1] < 1/3-5/60) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (1/3-7/60 < data[i,1] < 1/3-6/60) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (1/3-8/60 < data[i,1] < 1/3-7/60) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (1/3-9/60 < data[i,1] < 1/3-8/60) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (1/3-10/60 < data[i,1] < 1/3-9/60) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (1/3-11/60 < data[i,1] < 1/3-10/60) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (1/3-12/60 < data[i,1] < 1/3-11/60) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (1/3-13/60 < data[i,1] < 1/3-12/60) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (1/3-14/60 < data[i,1] < 1/3-13/60) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (1/3-15/60 < data[i,1] < 1/3-14/60) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (1/3-16/60 < data[i,1] < 1/3-15/60) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (1/3-17/60 < data[i,1] < 1/3-16/60) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (1/3-18/60 < data[i,1] < 1/3-17/60) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (1/3-19/60 < data[i,1] < 1/3-18/60) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,1] < 1/3-19/60) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 1
# Number of points inside the polygon: 1
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 5
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 4
# Number of points inside the polygon: 6
# Number of points inside the polygon: 5
# Number of points inside the polygon: 6
# Number of points inside the polygon: 5
# Number of points inside the polygon: 7
# Number of points inside the polygon: 4
# Number of points inside the polygon: 5
# Number of points inside the polygon: 5
# Number of points inside the polygon: 6
# Number of points inside the polygon: 5
# Number of points inside the polygon: 5
# 中心复合差异 CCD_p(P): 0.01666666666666667
# Number of points inside the polygon: 4
# Number of points inside the polygon: 7
# Number of points inside the polygon: 5
# ...

# %%
import numpy as np
from scipy.integrate import nquad
from shapely.geometry import Point, Polygon
import pandas as pd


#######模拟数据
# AR数据
data2 = pd.read_csv('data102A_points.csv',header=None)
data2 = np.array(data2)
# SR数据
data3 = pd.read_csv('data102S_points.csv',header=None)
data3 = np.array(data3)
# IRT数据
data1 = pd.read_csv('data102I_points.csv',header=None)
data1 = np.array(data1)

n = 100

datal =[data1,data2,data3]
for data in datal :
########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside1 = 0
 for i in range(n):
    if (1/3-1/60 < data[i,1] < 1/3) :
        count_inside1 += 1
 print(f"Number of points inside the polygon: {count_inside1}")
 p1 = count_inside1 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside2 = 0
 for i in range(n):
    if (1/3-2/60 < data[i,1] < 1/3-1/60) :
        count_inside2 += 1
 print(f"Number of points inside the polygon: {count_inside2}")
 p2 = count_inside2 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside3 = 0
 for i in range(n):
    if (1/3-3/60 < data[i,1] < 1/3-2/60) :
        count_inside3 += 1
 print(f"Number of points inside the polygon: {count_inside3}")
 p3 = count_inside3 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside4 = 0
 for i in range(n):
    if (1/3-4/60 < data[i,1] < 1/3-3/60) :
        count_inside4 += 1
 print(f"Number of points inside the polygon: {count_inside4}")
 p4 = count_inside4 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside5 = 0
 for i in range(n):
    if (1/3-5/60 < data[i,1] < 1/3-4/60) :
        count_inside5 += 1
 print(f"Number of points inside the polygon: {count_inside5}")
 p5 = count_inside5 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside6 = 0
 for i in range(n):
    if (1/3-6/60 < data[i,1] < 1/3-5/60) :
        count_inside6 += 1
 print(f"Number of points inside the polygon: {count_inside6}")
 p6 = count_inside6 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside7 = 0
 for i in range(n):
    if (1/3-7/60 < data[i,1] < 1/3-6/60) :
        count_inside7 += 1
 print(f"Number of points inside the polygon: {count_inside7}")
 p7 = count_inside7 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside8 = 0
 for i in range(n):
    if (1/3-8/60 < data[i,1] < 1/3-7/60) :
        count_inside8 += 1
 print(f"Number of points inside the polygon: {count_inside8}")
 p8 = count_inside8 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside9 = 0
 for i in range(n):
    if (1/3-9/60 < data[i,1] < 1/3-8/60) :
        count_inside9 += 1
 print(f"Number of points inside the polygon: {count_inside9}")
 p9 = count_inside9 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside10 = 0
 for i in range(n):
    if (1/3-10/60 < data[i,1] < 1/3-9/60) :
        count_inside10 += 1
 print(f"Number of points inside the polygon: {count_inside10}")
 p10 = count_inside10 / n
 ########计算N(Dk)/N(D)
# 统计落在D1内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside11 = 0
 for i in range(n):
    if (1/3-11/60 < data[i,1] < 1/3-10/60) :
        count_inside11 += 1
 print(f"Number of points inside the polygon: {count_inside11}")
 p11 = count_inside11 / n

# 统计落在D2内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside12 = 0
 for i in range(n):
    if (1/3-12/60 < data[i,1] < 1/3-11/60) :
        count_inside12 += 1
 print(f"Number of points inside the polygon: {count_inside12}")
 p12 = count_inside12 / n

# 统计落在D3内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside13 = 0
 for i in range(n):
    if (1/3-13/60 < data[i,1] < 1/3-12/60) :
        count_inside13 += 1
 print(f"Number of points inside the polygon: {count_inside13}")
 p13 = count_inside13 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside14 = 0
 for i in range(n):
    if (1/3-14/60 < data[i,1] < 1/3-13/60) :
        count_inside14 += 1
 print(f"Number of points inside the polygon: {count_inside14}")
 p14 = count_inside14 / n

# 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside15 = 0
 for i in range(n):
    if (1/3-15/60 < data[i,1] < 1/3-14/60) :
        count_inside15 += 1
 print(f"Number of points inside the polygon: {count_inside15}")
 p15 = count_inside15 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside16 = 0
 for i in range(n):
    if (1/3-16/60 < data[i,1] < 1/3-15/60) :
        count_inside16 += 1
 print(f"Number of points inside the polygon: {count_inside16}")
 p16 = count_inside16 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside17 = 0
 for i in range(n):
    if (1/3-17/60 < data[i,1] < 1/3-16/60) :
        count_inside17 += 1
 print(f"Number of points inside the polygon: {count_inside17}")
 p17 = count_inside17 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside18 = 0
 for i in range(n):
    if (1/3-18/60 < data[i,1] < 1/3-17/60) :
        count_inside18 += 1
 print(f"Number of points inside the polygon: {count_inside18}")
 p18 = count_inside18 / n

 # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside19 = 0
 for i in range(n):
    if (1/3-19/60 < data[i,1] < 1/3-18/60) :
        count_inside19 += 1
 print(f"Number of points inside the polygon: {count_inside19}")
 p19 = count_inside19 / n

  # 统计落在D4内的点的数量
# 创建四边形多边形对象（仅考虑x和y坐标）
 count_inside20 = 0
 for i in range(n):
    if (0 < data[i,1] < 1/3-19/60) :
        count_inside20 += 1
 print(f"Number of points inside the polygon: {count_inside20}")
 p20 = count_inside20 / n


 sum1 = (abs(p1-(1/20))** (2)+abs(p2-(1/20))** (2)+abs(p3-(1/20))** (2)+abs(p4-(1/20))** (2)+abs(p5-(1/20))** (2)+abs(p6-(1/20))** (2)+abs(p7-(1/20))** (2)+abs(p8-(1/20))** (2)+abs(p9-(1/20))** (2)+abs(p10-(1/20))** (2)+abs(p11-(1/20))** (2)+abs(p12-(1/20))** (2)+abs(p13-(1/20))** (2)+abs(p14-(1/20))** (2)+abs(p15-(1/20))** (2)+abs(p16-(1/20))** (2)+abs(p17-(1/20))** (2)+abs(p18-(1/20))** (2)+abs(p19-(1/20))** (2)+abs(p20-(1/20))** (2)) / 20

########### 计算 CCD_2
 CCD_p = (sum1 ** (1/2))

 print("中心复合差异 CCD_p(P):", CCD_p)
# Out:
# Number of points inside the polygon: 1
# Number of points inside the polygon: 2
# Number of points inside the polygon: 4
# Number of points inside the polygon: 3
# Number of points inside the polygon: 5
# Number of points inside the polygon: 4
# Number of points inside the polygon: 5
# Number of points inside the polygon: 7
# Number of points inside the polygon: 4
# Number of points inside the polygon: 7
# Number of points inside the polygon: 6
# Number of points inside the polygon: 5
# Number of points inside the polygon: 6
# Number of points inside the polygon: 4
# Number of points inside the polygon: 7
# Number of points inside the polygon: 7
# Number of points inside the polygon: 6
# Number of points inside the polygon: 6
# Number of points inside the polygon: 5
# Number of points inside the polygon: 6
# 中心复合差异 CCD_p(P): 0.016431676725154987
# Number of points inside the polygon: 8
# Number of points inside the polygon: 6
# Number of points inside the polygon: 4
# ...
